# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
csv_file_path = '/home/lucas/UFOP/ple_2020/analise_midias_sociais/final-work/data/all_pp_posts_haddad_replaced_to_empty_removing_other_words.csv'
df_candidate = pd.read_csv(csv_file_path,encoding = 'utf-8')

# %%
# convertendo o tipo data que esta como string em objeto no formato data
df_candidate["created_time"] = pd.to_datetime(df_candidate['created_time'])

# %%
df_candidate.head(15)
# Out:
#                 created_time                                id  \
# 0  2020-02-29 11:23:27+00:00  904277726319518_2878974912183113
# 1  2020-02-29 09:21:22+00:00  904277726319518_2878783568868914
# 2  2020-02-28 00:14:25+00:00  904277726319518_2875616525852285
# 3  2020-02-26 12:12:56+00:00  904277726319518_2872245456189392
# 4  2020-02-26 00:58:59+00:00  904277726319518_2871255852955019
# 5  2020-02-24 19:51:01+00:00  904277726319518_2868531243227480
# 6  2020-02-22 13:03:28+00:00  904277726319518_2863199017094036
# 7  2020-02-22 00:18:55+00:00  904277726319518_2862087573871847
# 8  2020-02-20 11:28:49+00:00  904277726319518_2858610960886175
# 9  2020-02-18 20:38:19+00:00  904277726319518_2855332637880674
# 10 2020-02-18 20:17:48+00:00  904277726319518_2855299197884018
# 11 2020-02-17 10:51:16+00:00  904277726319518_2852021088211829
# 12 2020-02-15 11:59:30+00:00  904277726319518_2847768221970449
# 13 2020-02-13 22:16:20+00:00  904277726319518_2844398988974039
# 14 2020-02-12 23:32:25+00:00  904277726319518_2842368455843759
#
#                                 message_max_processed  \
# 0   bolsonavirus nada erroneo considerar bolsonaro...
# 1   bolsonavirus nada erroneo considerar bolsonaro...
# 2   cristiano zanin advogado lula fernando haddad ...
# 3   disney pao ano governo bolsonaro sabia falta d...
# 4   bolsonaro tudo indica cometeu crime responsabi...
# 5   impacto fundeb criamos qualidade educacao nord...
# 6   cronica semana podemos descuidar dois problema...
# 7      bem falaram carnaval rua sp ia rolar triste ne
# 8   clara tentativa desestabilizar melhores govern...
# 9   brasilia discutindo oposicao brasil justo demo...
# 10                   ser abjeto presidencia republica
# 11  bolsonaro sempre odiou nordeste impacto corte ...
# 12  coluna semana livros estados tentam institucio...
# 13  vaticano encontro lula papa francisco conversa...
# 14            cara idiota vai ter pedir desculpas vez
#
#                               m_m_p_replaced_to_empty  shares  \
# 0   bolsonavirus nada erroneo considerar   acident...     818
# 1   bolsonavirus nada erroneo considerar   raio ce...     477
# 2   cristiano zanin advogado lula   discutem novid...     540
# 3   disney pao ano governo   sabia falta dinheiro ...    1068
# 4     tudo indica cometeu crime responsabilidade p...    1369
# 5   impacto fundeb criamos qualidade educacao nord...    3249
# 6   cronica semana podemos descuidar dois problema...     528
# 7      bem falaram carnaval rua sp ia rolar triste ne    1289
# 8   clara tentativa desestabilizar melhores govern...     588
# 9   brasilia discutindo oposicao brasil justo demo...     541
# 10                   ser abjeto presidencia republica     937
# 11    sempre odiou nordeste impacto corte bolsas p...    2674
# 12  coluna semana livros estados tentam institucio...     252
# 13  vaticano encontro lula papa francisco conversa...     966
# 14            cara idiota vai ter pedir desculpas vez    4111
#
#              status_type                                       full_picture  \
# 0           shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 1           shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 2   mobile_status_update  https://scontent-gru2-2.xx.fbcdn.net/v/t15.525...
# 3           shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 4   mobile_status_update                                               None
# 5           shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 6           shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 7           added_photos  https://scontent-gru1-1.xx.fbcdn.net/v/t1.0-9/...
# 8   mobile_status_update                                               None
# 9           added_photos  https://scontent-gru2-1.xx.fbcdn.net/v/t1.0-9/...
# 10          shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 11          shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 12          shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
# 13          added_photos  https://scontent-gru1-1.xx.fbcdn.net/v/t1.0-9/...
# 14          shared_story  https://external-gru1-1.xx.fbcdn.net/safe_imag...
#
#     reactions_like  reactions_haha  reactions_wow  reactions_sad  \
# 0             4996             209             19             40
# 1             2602              84             14             26
# 2             3068             120             23              4
# 3             3148              48             24           1306
# 4            21619             524             79             68
# 5            10571              86             45              9
# 6             2718              80             31            130
# 7            29857            1003            132             25
# 8             9914             223             12             19
# 9             9555             369             32              3
# 10            4588             177             44            723
# 11            3466              65             47           1307
# 12            1693              33              8             13
# 13           12894             325             48              6
# 14            8865             190            140            893
#
#     reactions_angry  reactions_love  has_textual_message
# 0                58             636                 True
# 1                19             130                 True
# 2                20             140                 True
# 3               616               8                 True
# 4                77            1923                 True
# 5                 2            2635                 True
# 6                34              31                 True
# 7                14           12585                 True
# 8                 7             820                 True
# 9                20            2114                 True
# 10             2333              36                 True
# 11             2333               9                 True
# 12                3             168                 True
# 13               22            5176                 True
# 14             4436              71                 True

# %%
#===========================================================================
# obter o dataframe com os posts do candidato no ano de 2018
#===========================================================================

time_mask = (df_candidate['created_time'] >= '2018-01-01') & (df_candidate['created_time'] <= '2018-12-31')

df_election = df_candidate[time_mask]

# %%
#===========================================================================
# ordenando df_election por reacoes sad 
#===========================================================================

election_df_sorted_by_sad = df_election.sort_values('reactions_sad', ascending=False) # ordenando o df por sad

election_df_sorted_by_sad
# Out:
#                   created_time                                id  \
# 656  2018-10-27 21:09:41+00:00  904277726319518_2010111395736140
# 650  2018-10-29 02:17:11+00:00  904277726319518_2012077898872823
# 653  2018-10-28 23:06:10+00:00  904277726319518_1886255711490923
# 753  2018-10-16 23:48:35+00:00  904277726319518_1990563791024234
# 682  2018-10-25 18:23:45+00:00  904277726319518_2006175762796370
# ...                        ...                               ...
# 867  2018-10-02 13:39:37+00:00  904277726319518_1077256002451688
# 1126 2018-08-28 14:45:26+00:00  904277726319518_2120170958226021
# 1125 2018-08-28 15:00:31+00:00   904277726319518_216017482606184
# 1123 2018-08-28 23:24:41+00:00  904277726319518_2059063804424269
# 1149 2018-08-23 20:24:08+00:00   904277726319518_473697683125319
#
#                                   message_max_processed  \
# 656   depoimentos torturados ditadura chocantes poss...
# 650   coloco vida disposicao desse pais medo estarem...
# 653
# 753                        ditadura nunca tortura nunca
# 682   anos vladimir herzog assassinado ditadura doic...
# ...                                                 ...
# 867                dia luta dia brasil compartilhe vote
# 1126  caminhada goncalo rj fernando haddad vice lula...
# 1125  caminhada goncalo rj fernando haddad vice lula...
# 1123  ato lulapresidente minas gerais fernando hadda...
# 1149  caminhada campanha lula joao pessoa paraiba go...
#
#                                 m_m_p_replaced_to_empty  shares   status_type  \
# 656   depoimentos torturados ditadura chocantes poss...   28182   added_video
# 650   coloco vida disposicao desse pais medo estarem...   19286  added_photos
# 653                                                       22892   added_video
# 753                        ditadura nunca tortura nunca   25727   added_video
# 682   anos vladimir herzog assassinado ditadura doic...    9887   added_video
# ...                                                 ...     ...           ...
# 867                dia luta dia brasil compartilhe vote     840   added_video
# 1126    caminhada goncalo rj   vice lula lulapresidente     684   added_video
# 1125    caminhada goncalo rj   vice lula lulapresidente     943   added_video
# 1123       ato lulapresidente minas gerais     pimentel     645   added_video
# 1149  caminhada campanha lula   pessoa paraiba gover...    1285   added_video
#
#                                            full_picture  reactions_like  \
# 656   https://scontent-gru2-2.xx.fbcdn.net/v/t15.134...           13524
# 650   https://scontent-gru2-2.xx.fbcdn.net/v/t1.0-9/...          100942
# 653   https://scontent-gru2-2.xx.fbcdn.net/v/t15.525...           53323
# 753   https://scontent-gru1-1.xx.fbcdn.net/v/t15.525...           11484
# 682   https://scontent-gru1-1.xx.fbcdn.net/v/t15.134...            8325
# ...                                                 ...             ...
# 867   https://scontent-gru1-1.xx.fbcdn.net/v/t15.525...            1327
# 1126  https://scontent-gru2-2.xx.fbcdn.net/v/t15.525...            1943
# 1125  https://scontent-gru2-1.xx.fbcdn.net/v/t15.525...            1792
# 1123  https://scontent-gru1-1.xx.fbcdn.net/v/t15.525...            1758
# 1149  https://scontent-gru1-1.xx.fbcdn.net/v/t15.525...            1905
#
#       reactions_haha  reactions_wow  reactions_sad  reactions_angry  \
# 656              504            138           7424              455
# 650             6454             98           6922              202
# 653             6677            180           6753              900
# 753              960            124           3195              546
# 682              168             34           2823              111
# ...              ...            ...            ...              ...
# 867               14             19              0               14
# 1126              11             17              0               10
# 1125               9             18              0                2
# 1123               7             17              0                8
# 1149              15             22              0               18
#
#       reactions_love  has_textual_message
# 656              866                 True
# 650            60618                 True
# 653            68080                False
# 753              991                 True
# 682              853                 True
# ...              ...                  ...
# 867              232                 True
# 1126             337                 True
# 1125             303                 True
# 1123             539                 True
# 1149             419                 True
#
# [585 rows x 14 columns]
