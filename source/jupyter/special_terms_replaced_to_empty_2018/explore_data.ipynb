# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer,TfidfTransformer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_file_path = '/home/lucas/UFOP/ple_2020/analise_midias_sociais/final-work/data/all_pp_posts_bolsonaro_replaced_to_empty.csv'
df_candidate = pd.read_csv(csv_file_path,encoding = 'utf-8')

# %%
# convertendo o tipo data que esta como string em objeto no formato data
df_candidate["created_time"] = pd.to_datetime(df_candidate['created_time'])

# %%
df_candidate.head(15)
# Out:
#                 created_time                                id  \
# 0  2020-03-22 18:47:55+00:00  211857482296579_1826486634166981
# 1  2020-03-22 16:30:39+00:00  211857482296579_1826339070848404
# 2  2020-03-22 13:37:26+00:00  211857482296579_1826130007535977
# 3  2020-03-22 11:07:01+00:00  211857482296579_1825937284221916
# 4  2020-03-22 02:06:48+00:00  211857482296579_1825422034273441
# 5  2020-03-21 22:22:48+00:00  211857482296579_1825061764309468
# 6  2020-03-21 18:36:01+00:00  211857482296579_1824728371009474
# 7  2020-03-21 11:33:30+00:00  211857482296579_1824261207722857
# 8  2020-03-21 02:37:00+00:00  211857482296579_1823872341095077
# 9  2020-03-21 00:16:41+00:00  211857482296579_1823743497774628
# 10 2020-03-20 22:45:20+00:00  211857482296579_1823657957783182
# 11 2020-03-20 20:20:22+00:00  211857482296579_1823512861131025
# 12 2020-03-20 18:55:59+00:00  211857482296579_1823438294471815
# 13 2020-03-20 18:07:20+00:00  211857482296579_1823387084476936
# 14 2020-03-20 15:32:31+00:00  211857482296579_1823236217825356
#
#                                 message_max_processed  \
# 0   agora videoconferencia presidente jair bolsona...
# 1   inscricoes selecao profissionais atuacao progr...
# 2   ministerio saude ministro mandetta reuniao vir...
# 3   governo federal distribui milhoes testes rapid...
# 4   chama precaucao medicamento barato caso venha ...
# 5   reconheco seriedade momento temor muitos brasi...
# 6   hospital albert einstein possivel cura pacient...
# 7       dois dedos prosa ratinho assista link youtube
# 8   assinei medida provisoria deixando claro ser c...
# 9                               via eduardo bolsonaro
# 10  ministro tarcisio barreiras estados colocam ri...
# 11                                      coletiva vivo
# 12
# 13
# 14  setor sucroenergetico doara alcool fabricacao ...
#
#                               m_m_p_replaced_to_empty  shares  \
# 0   agora videoconferencia presidente   presidente...   23151
# 1   inscricoes selecao profissionais atuacao progr...    5703
# 2   ministerio saude ministro mandetta reuniao vir...   11818
# 3   governo federal distribui milhoes testes rapid...   39284
# 4   chama precaucao medicamento barato caso venha ...   27236
# 5   reconheco seriedade momento temor muitos brasi...   40794
# 6   hospital albert einstein possivel cura pacient...  201803
# 7       dois dedos prosa ratinho assista link youtube   33971
# 8   assinei medida provisoria deixando claro ser c...    9174
# 9                                       via eduardo      8150
# 10  ministro tarcisio barreiras estados colocam ri...    8900
# 11                                      coletiva vivo    3614
# 12                                                       2073
# 13                                                       2306
# 14  setor sucroenergetico doara alcool fabricacao ...    7882
#
#              status_type                                       full_picture  \
# 0           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-0/p180x54...
# 1   mobile_status_update                                               None
# 2           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-0/p180x54...
# 3   mobile_status_update                                               None
# 4           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-9/9052732...
# 5           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-9/9065012...
# 6            added_video  https://scontent.xx.fbcdn.net/v/t15.5256-10/75...
# 7            added_video  https://scontent.xx.fbcdn.net/v/t15.5256-10/83...
# 8           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-9/s720x72...
# 9           added_photos  https://scontent.xx.fbcdn.net/v/t1.0-0/p600x60...
# 10           added_video  https://scontent.xx.fbcdn.net/v/t15.5256-10/83...
# 11  mobile_status_update  https://scontent.xx.fbcdn.net/v/t15.5256-10/69...
# 12  mobile_status_update  https://scontent.xx.fbcdn.net/v/t15.5256-10/80...
# 13  mobile_status_update  https://scontent.xx.fbcdn.net/v/t15.5256-10/75...
# 14           added_video  https://scontent.xx.fbcdn.net/v/t15.5256-10/83...
#
#     reactions_like  reactions_haha  reactions_wow  reactions_sad  \
# 0           129465             147            318             21
# 1            52238             128             61              5
# 2            97986              73            141             16
# 3           165539              88            393             20
# 4           162513             968            318             88
# 5           305358             918            478            266
# 6           215237             480            815             60
# 7           106117             336            317            113
# 8           112873             181            200            106
# 9            79762             435            111             13
# 10           36696              24             88             27
# 11           34117              50             45             27
# 12           15700              20             39             14
# 13           16806              67             34              8
# 14           36271              24             75              4
#
#     reactions_angry  reactions_love  has_textual_message
# 0               112           10345                 True
# 1                43            2514                 True
# 2                65            6292                 True
# 3                68           16747                 True
# 4               509           20723                 True
# 5              1267           48834                 True
# 6               431           34278                 True
# 7               624           15368                 True
# 8              1121            7582                 True
# 9               160            6480                 True
# 10               55            2253                 True
# 11              116            1260                 True
# 12               55             619                 True
# 13               30             677                 True
# 14               17            3212                 True

# %%
n_total_posts = len(df_candidate)
print('número total de posts: {0}'.format(str(n_total_posts)))
# Out:
# número total de posts: 3646

# %%
n_posts_with_textual_messages = df_candidate[df_candidate.has_textual_message == True].shape[0]
n_posts_without_textual_messages = df_candidate[df_candidate.has_textual_message == False].shape[0]

print('número de posts com mensagens textuais: {0}'.format(str(n_posts_with_textual_messages)))
print('número de posts sem mensagens textuais: {0}'.format(str(n_posts_without_textual_messages)))
# Out:
# número de posts com mensagens textuais: 3394
# número de posts sem mensagens textuais: 252

# %%
#============================================================================================
# realizando o tf idf no df['pre_processed_message'] do corpus inteiro
#============================================================================================

# tf idf é uma medida estatística que tem o intuito de indicar a importância de uma palavra 
# de um documento em relação a uma coleção de documentos ou em um corpus linguístico.

def sort_columns(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)


def extract_top_n_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    sorted_items = sorted_items[:topn]
    score_vals = []
    feature_vals = []
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    return results

cv = CountVectorizer()

word_count_vector=cv.fit_transform(df_candidate['m_m_p_replaced_to_empty'])

tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)

# you only needs to do this once, this is a mapping of index to 
feature_names=cv.get_feature_names()

# get the document that we want to extract keywords from
corpus=' '.join(df_candidate['m_m_p_replaced_to_empty'])

#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

#sort the tf-idf vectors by descending order of scores
sorted_items=sort_columns(tf_idf_vector.tocoo())

#extract only the top n; n here is 10
keywords=extract_top_n_from_vector(feature_names,sorted_items,10)

# now print the results
print("\nDocument")
print(corpus)
print("\n===Keywords===")
for key in keywords:
    print(key,keywords[key])
# Out:
# Document
# agora videoconferencia presidente   presidente bndes anunciam medidas manutencao empregos transferencia r bilhoes conta pispasep fgts refinanciamentos novas linhas creditos recursos ordem r bilhoes inscricoes selecao profissionais atuacao programa medicos renovacao adesao municipios prorrogadas vao ate domingo h detalhes ministerio saude ministerio saude ministro mandetta reuniao virtual sobre covid prefeitos capitais brasil alinhamento ideias explicacoes troca experiencias combate coronavirus ministerio saude flavio   governo federal distribui milhoes testes rapidos covid todo brasil serem aplicados pontos facil acesso populacao sao aproximadamente milhoes testes total cinco milhoes enviados todos estados ainda marco meio parcerias anuncios empresarios cada dia colocam disposicao juntos possamos minimizar impactos covid testes rapidos poderao ser realizados locais facil acesso farmacias escolas postos drivethru amostras sao coletadas paciente saia proprio veiculo estrategia adotada sucesso coreia sul chama precaucao medicamento barato caso venha ser comprovada eficacia combate covid estaremos preparados atender todos brasileiros rapidamente ainda testes medicamento apresentem ineficacia tratamento especifico coronavirus ja comprovadamente eficaz combate outros tipos doenca malaria constando inclusive guia vigilancia epidemiologica atualizado enquanto uns seguem buscando caos seguimos buscando solucoes proteger nacao reconheco seriedade momento temor muitos brasileiros ante ameaca coronavirus governo segue trabalhando intensamente tomara todas medidas possiveis conter transmissao covid tambem dever impedir panico tome conta pais complicaria ainda situacao objetivo mostrar superaremos obstaculo tratado questao coragem tranquilidade forma alguma usarei momento fazer demagogia todo modo familias hoje sofrem perda entes conta desta epidemia solidariedade perdas tambem sao afinal todos grande familia doulhes certeza lutarei todas forcas proteger nacao peco deus cada vez sabedoria enfrentarmos tempestade peco todos sigam recomendacoes saude muita serenidade nao percam fe deus amado brasil certeza venceremos batalha brevemente hospital albert einstein possivel cura pacientes covid link youtube dois dedos prosa ratinho assista link youtube assinei medida provisoria deixando claro ser competencia federal observando criterios tecnicos responsaveis definicao sobre fechamento nao aeroportos rodoviasestradas federais via eduardo   ministro tarcisio barreiras estados colocam risco transporte itens basicos medicos acoes atualizadas governo combate coronavirus liberacao r mi pque instituicoes ensino possam comprar alcool gel produtos higiene suspensao visitas presidios federais recursos financeiros unidades saude cidades todo brasil ampliarem funcionamento substituicao aulas presenciais aulas distancia restricao entrada estrangeiros fronteiras pais projeto simplificacao temporaria regras trabalhistas trabalhador empregador poderao celebrar acordos individuais respeitados limites constituicao auxilio emergencial r bi ptrabalhadores informais r bi ppequenas microempresas facilitacao renegociacao creditos desburocratizacao pimportacao insumos materiaprima prorrogacao prazo pagamento fgts injetando r bi economia adiamento pagamento simples nacional ceconomia r bi ppequenas medias empresas reducao contribuicoes po sistema s beneficiando empregadores mil medicos preforco combate virus instalacao mil leitos brasil patendimento pacientes distribuicao mil kits pdiagnostico coronavirus r mi pos estados repasse r bi fundo dpvat pcombate coronavirus antecipacao parcela aposentados pensionistas suspensao prova vida dias sinterrupcao pagamentos inss antecipacao abono salarial pjunho injetando r bi economia inclusao milhao pessoas bolsa familia cliberacao r bi r bi ppequenas microempresas criacao comite crise psupervisao monitoramento impactos covid criacao comite especialistas rede virus ppromover pesquisas relacionadas coronavirus liberacao r bi preduzir  ...
#
# ===Keywords===
# brasil 0.261
# nao 0.24
# pt 0.14
# todos 0.136
# governo 0.131
# sao 0.124
# sobre 0.115
# youtube 0.115
# ministerio 0.113
# link 0.113

# %%
def get_top_n_words(n_top_words, count_vectorizer, text_data):
    '''
    returns a tuple of the top n words in a sample and their 
    accompanying counts, given a CountVectorizer object and text sample
    '''
    vectorized_headlines = count_vectorizer.fit_transform(text_data.values)
    vectorized_total = np.sum(vectorized_headlines, axis=0)
    word_indices = np.flip(np.argsort(vectorized_total)[0,:], 1)
    word_values = np.flip(np.sort(vectorized_total)[0,:],1)
    
    word_vectors = np.zeros((n_top_words, vectorized_headlines.shape[1]))
    for i in range(n_top_words):
        word_vectors[i,word_indices[0,i]] = 1

    words = [word[0].encode('ascii').decode('utf-8') for 
             word in count_vectorizer.inverse_transform(word_vectors)]

    return (words, word_values[0,:n_top_words].tolist()[0])

# %%
#=======================================================================
# visualização das top palavras
#=======================================================================

count_vectorizer = CountVectorizer()
words, word_values = get_top_n_words(n_top_words=15,
                                     count_vectorizer=count_vectorizer, 
                                     text_data=df_candidate['m_m_p_replaced_to_empty'])

for index in range(len(word_values)):
    print('{0} : {1}'.format(str(words[index]),str(word_values[index])))
    
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(range(len(words)), word_values);
ax.set_xticks(range(len(words)));
ax.set_xticklabels(words, rotation='vertical');
ax.set_title('Palavras com mais ocorências após o processamento total');
ax.set_xlabel('Palavra');
ax.set_ylabel('Número de ocorências');
plt.show()
# Out:
# brasil : 876
# nao : 712
# pt : 349
# todos : 342
# governo : 310
# sao : 299
# youtube : 279
# link : 272
# sobre : 272
# obrigado : 260
# hoje : 256
# ministerio : 244
# presidente : 232
# eduardo : 208
# dia : 200
